# %%
job_info = (
            f"Company:\n"
            f"Job Title: \n"
            f"Job Description:\n\n\n"
        )

role = """You are an ATS resume expert and LaTeX developer.
Your task is to tailor the provided LaTeX resume template to the provided job description 
using my experience  and the job description below.\n"""
prompt = role + job_info

# %%
print(prompt)
# Out:
# You are an ATS resume expert and LaTeX developer.
# Your task is to tailor the provided LaTeX resume template to the provided job description
# using my experience  and the job description below.
# Company:
# Job Title:
# Job Description:
